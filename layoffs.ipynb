# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
G=2000
E=4000
H=500
R=8000
S=25000
N=50000

g=0.15
e=0.1
h=0.25
r=0.1
s=0.1
n=0.05

R_g=2000000
R_e=4500000
R_h=10000000
R_r=5000000
R_s=12000000
R_n=30000000

w_g=R_g/G
w_e=R_e/E
w_h=R_h/H
w_r=R_r/R
w_s=R_s/S
w_n=R_n/N

# %%
i=0

listG=[]
listE=[]
listH=[]
listR=[]
listS=[]

list=[]


G_1=0
S_1=0
R_1=0
H_1=0
E_1=0
N_1=1000

while i<10000:
    R_g=R_g-g*w_n*N_1-g*w_e*E_1-g*w_h*H_1-g*w_r*R_1-g*w_s*S_1-g*w_g*G_1
    R_e=R_e-e*w_n*N_1-e*w_e*E_1-e*w_h*H_1-e*w_r*R_1-e*w_s*S_1-e*w_g*G_1
    R_h=R_h-h*w_n*N_1-h*w_e*E_1-h*w_h*H_1-h*w_r*R_1-h*w_s*S_1-h*w_g*G_1
    R_r=R_r-r*w_n*N_1-r*w_e*E_1-r*w_h*H_1-r*w_r*R_1-r*w_s*S_1-r*w_g*G_1
    R_s=R_s-s*w_n*N_1-s*w_e*E_1-s*w_h*H_1-s*w_r*R_1-s*w_s*S_1-s*w_g*G_1
    
    G_=R_g/w_g
    E_=R_e/w_e
    H_=R_h/w_h
    R_=R_r/w_r
    S_=R_s/w_s
    N_=R_n/w_n
    
    G_1=G-G_
    S_1=S-S_
    R_1=R-R_
    H_1=H-H_
    E_1=E-E_
    N_1=N-N_
    
    G=G_
    E=E_
    H=H_
    R=R_
    S=S_
    N=N_
    
    listG.append(R_g)
    listE.append(R_e)
    listH.append(R_h)
    listR.append(R_r)
    listS.append(R_s)

    
    
    i+=1

# %%
listG
# Out:
# [1910000.0,
#  1847000.0,
#  1802900.0,
#  1772030.0,
#  1750421.0,
#  1735294.6999999997,
#  1724706.2899999998,
#  1717294.403,
#  1712106.0821000002,
#  1708474.2574699998,
#  1705931.9802289999,
#  1704152.3861603006,
#  1702906.6703122107,
#  1702034.6692185486,
#  1701424.2684529852,
#  1700996.9879170903,
#  1700697.891541964,
#  1700488.5240793761,
#  1700341.966855564,
#  1700239.3767988961,
#  1700167.5637592284,
#  1700117.2946314614,
#  1700082.106242024,
#  1700057.4743694176,
#  1700040.2320585935,
#  1700028.1624410164,
#  1700019.713708713,
#  1700013.7995961003,
#  1700009.6597172723,
#  1700006.7618020927,
#  1700004.7332614665,
#  1700003.3132830285,
#  1700002.3192981216,
#  1700001.6235086862,
#  1700001.1364560812,
#  1700000.7955192572,
#  1700000.55686348,
#  1700000.3898044352,
#  1700000.272863104,
#  1700000.1910041727,
#  1700000.1337029205,
#  1700000.0935920447,
#  1700000.0655144316,
#  1700000.0458601026,
#  1700000.0321020724,
#  1700000.0224714507,
# ...

# %%
plt.plot(listG)
plt.ylim(0,)
# Out:
# (0.0, 1920500.0000000005)

# %%
G
# Out:
# 1699.9999999999911
